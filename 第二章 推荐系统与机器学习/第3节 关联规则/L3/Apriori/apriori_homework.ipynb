# %%
import pandas as pd
from efficient_apriori import apriori

# %%
data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
data.loc[1].dropna().unique()
# Out:
# array(['burgers', 'meatballs', 'eggs'], dtype=object)

# %%
import numpy as np
transcation = np.array([data.loc[i].dropna().unique() for i in range(data.shape[0])])

# %%
items, rules = apriori(transcation, min_support=0.1, min_confidence=0.5)
print("频繁项集：", items)
print("关联规则：", rules)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-6fea3834a40c> in <module>()
# ----> 1 items, rules = apriori(transcation, min_support=0.1, min_confidence=0.5)
#       2 print("频繁项集：", items)
#       3 print("关联规则：", rules)
#
# D:\Anaconda3\lib\site-packages\efficient_apriori\apriori.py in apriori(transactions, min_support, min_confidence, max_length, verbosity, output_transaction_ids)
#      67         max_length,
#      68         verbosity,
# ---> 69         output_transaction_ids,
#      70     )
#      71
#
# D:\Anaconda3\lib\site-packages\efficient_apriori\itemsets.py in itemsets_from_transactions(transactions, min_support, max_length, verbosity, output_transaction_ids)
#     323     counter = (
#     324         _CounterWithIds()
# --> 325         if (transactions and output_transaction_ids)
#     326         else _Counter()
#     327     )
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
